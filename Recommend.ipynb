# %%
import numpy as np 
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
data = pd.read_csv('main_data.csv')

# %%
data
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6090        Pete Docter             Jamie Foxx          Tina Fey
# 6091   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6092        Regina King      Kingsley Ben-Adir         Eli Goree
# 6093    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6094   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6090         Graham Norton  Animation Comedy Fantasy Family
# 6091         YaYa Gosselin     Action Fantasy Family Comedy
# 6092           Aldis Hodge                            Drama
# 6093           Alison Brie             Thriller Crime Drama
# 6094          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6090                                               soul
# 6091                                   we can be heroes
# 6092                              one night in miami...
# 6093                              promising young woman
# 6094                                  pieces of a woman
#
#                                                    comb  movie_id
# 0     CCH Pounder Joel David Moore Wes Studi James C...     19995
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...       285
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...    206647
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...     49026
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...    140607
# ...                                                 ...       ...
# 6090  Jamie Foxx Tina Fey Graham Norton Pete Docter ...    508442
# 6091  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...    615677
# 6092  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...    661914
# 6093  Carey Mulligan Bo Burnham Alison Brie Emerald ...    582014
# 6094  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...    641662
#
# [6095 rows x 8 columns]

# %%
vector = cv.fit_transform(data['comb']).toarray()

# %%
vector.shape
# Out:
# (6095, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.24174689, 0.16903085, ..., 0.        , 0.        ,
#         0.        ],
#        [0.24174689, 1.        , 0.19069252, ..., 0.        , 0.        ,
#         0.        ],
#        [0.16903085, 0.19069252, 1.        , ..., 0.        , 0.1       ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.10540926,
#         0.12598816],
#        [0.        , 0.        , 0.1       , ..., 0.10540926, 1.        ,
#         0.11952286],
#        [0.        , 0.        , 0.        , ..., 0.12598816, 0.11952286,
#         1.        ]])

# %%
data[data['movie_title'] == 'soul'].index[0]
# Out:
# 6090

# %%
data
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6090        Pete Docter             Jamie Foxx          Tina Fey
# 6091   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6092        Regina King      Kingsley Ben-Adir         Eli Goree
# 6093    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6094   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6090         Graham Norton  Animation Comedy Fantasy Family
# 6091         YaYa Gosselin     Action Fantasy Family Comedy
# 6092           Aldis Hodge                            Drama
# 6093           Alison Brie             Thriller Crime Drama
# 6094          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6090                                               soul
# 6091                                   we can be heroes
# 6092                              one night in miami...
# 6093                              promising young woman
# 6094                                  pieces of a woman
#
#                                                    comb  movie_id
# 0     CCH Pounder Joel David Moore Wes Studi James C...     19995
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...       285
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...    206647
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...     49026
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...    140607
# ...                                                 ...       ...
# 6090  Jamie Foxx Tina Fey Graham Norton Pete Docter ...    508442
# 6091  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...    615677
# 6092  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...    661914
# 6093  Carey Mulligan Bo Burnham Alison Brie Emerald ...    582014
# 6094  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...    641662
#
# [6095 rows x 8 columns]

# %%
def recommend(movie):
    index = data[data['movie_title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:9]:
        print(data.iloc[i[0]].movie_title)

# %%
recommend('batman begins')
# Out:
# the dark knight
# the dark knight rises
# krull
# my hero academia: two heroes
# terminator salvation
# wrath of the titans
# clash of the titans
# exodus: gods and kings

# %%
import pickle

# %%
pickle.dump(data,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
